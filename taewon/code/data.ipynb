# %%
import pandas as pd

# CSV 파일 읽기
df = pd.read_csv('output.csv')

# target 열이 0인 행만 선택
target_0 = df[df['target'] == 0]

# 결과 출력
target_0[:30]
# Out:
#                     ID                                   text  target
# 1    ynat-v1_dev_00001                부산 7일 만에 시원한 비…폭염경보→주의보       0
# 8    ynat-v1_dev_00008  신도시 짓고 유휴부지 쓰고…수도권 30만가구 2021년부터 분양종합       0
# 9    ynat-v1_dev_00009                광주·전남 4∼6월 강수량 평년대비 44%       0
# 32   ynat-v1_dev_00032                  박수치는 2019 세계기자대회 참석자들       0
# 36   ynat-v1_dev_00036                    명왕성에 빙하 생긴 건 지형의 영향       0
# 43   ynat-v1_dev_00043            1900년 5월 개기일식 담은 활동사진 복원 공개       0
# 45   ynat-v1_dev_00045            오후 들어서도 전국 온통 꽁꽁…올겨울 첫 한파경보       0
# 48   ynat-v1_dev_00048                세월호와 삶의 관계 말하는 건 작가의 의무       0
# 50   ynat-v1_dev_00050            제주도 호우 예비특보…최고 120㎜ 이상 많은 비       0
# 58   ynat-v1_dev_00058                  북한날씨 대체로 맑음…일부 지역 소나기       0
# 66   ynat-v1_dev_00066         인천 오후 5시 대설주의보 해제…눈 5.8cm 쌓여종합       0
# 75   ynat-v1_dev_00075                과학의 죄악 꼬집는 커트 보니것의 블랙유머       0
# ...
